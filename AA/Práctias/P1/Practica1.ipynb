# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils
import practica01

from public_tests import compute_cost_test, compute_gradient_test
from LinearRegression import cost_test_obj, compute_gradient_obj
#name,platform,r-date,score,user score,developer,genre,players,critics,users
gamesData = pd.read_csv('data/games-data.csv')

#Ej1
# Limpieza de datos en utils.py
x = utils.cleanData(gamesData) 
# Representación de los datos
#x = utils.plot_data(x)

#Ej4
# Test con valores de prueba => public_test
#compute_cost_test(cost_test_obj)
#compute_gradient_test(compute_gradient_obj)

X,y=utils.load_data_csv('data/games-data.csv','score','user score')
#display(X,y)
#Test sobre el dataset => practica01
practica01.test_gradient(X, y)
practica01.test_gradient_iterative(X, y)
practica01.test_cost(X,y)
practica01.test_cost_iterative(X,y)
test_w, test_b = 0, 0
practica01.test_gradient_descent(X,y,test_w,test_b)

practica01.test_gradient_descent_iterative(X,y,test_w,test_b)
# Out:
# Iniciando test de gradiente vectorial
# Tiempo de procesamiento gradiente  vectorial: 0:00:00.000958
# Vectorial gradient at initial w, b (similar to)(-50.498559851122586 -6.988606075159082): -50.498559851122586 -6.988606075159082
# Tiempo de procesamiento gradiente  vectorial: 0:00:00
# Vectorial gradient at initial w, b (similar to)(-38.7005262336415 -5.369312042261976): -38.7005262336415 -5.369312042261976
# ----Compute gradient POO-------
# Testing: compute_gradient_test
# Using X with shape (4, 1)
# Case 1
# Case 1 passed!
# Case 2
# Case 2 passed!
# All tests passed!
# Iniciando test de gradiente iterativa
# Tiempo de procesamiento gradiente  iterativa: 0:00:00.027038
# Iterative gradient at initial w, b (similar to)(-50.498559851122586 -6.988606075159082): -50.49855985112268 -6.988606075159124
# Tiempo de procesamiento gradiente  iterativa: 0:00:00.023947
# ...
