# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils
from public_tests import compute_cost_test, compute_gradient_test
from LinearRegression import cost_test_obj, compute_gradient_obj
from practica01 import test_gradient,test_gradient_iterative,test_cost,test_cost_iterative,test_gradient_descent

#name,platform,r-date,score,user score,developer,genre,players,critics,users
gamesData = pd.read_csv('data/games-data.csv')

#Ej1
# Limpieza de datos en utils.py
x = utils.cleanData(gamesData) 
# Representación de los datos
#x = utils.plot_data(x)

#Ej4
# Test con valores de prueba => public_test
#compute_cost_test(cost_test_obj)
#compute_gradient_test(compute_gradient_obj)

X,y=utils.load_data_csv('data/games-data.csv','user score','score')
#display(X,y)
#Test sobre el dataset => practica01
test_gradient(X, y)
test_gradient_iterative(X, y)
test_cost(X,y)
test_cost_iterative(X,y)
test_w, test_b = 0,0
test_gradient_descent(X,y,test_w,test_b)
test_gradient_descent_iterative(X,y,test_w,test_b)
# Out:
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Vectorial gradient at initial w, b (similar to)(-50.498559851122586 -6.988606075159082): -50.02978415184723 -7.038664734730272
# Tiempo de procesamiento  vectorial: 0:00:00.000091
# Vectorial gradient at initial w, b (similar to)(-38.7005262336415 -5.369312042261976): -38.52003740485328 -5.440943519698456
# ----Compute gradient POO-------
# Testing: compute_gradient_test
# Using X with shape (4, 1)
# Tiempo de procesamiento  vectorial: 0:00:00.000025
# Case 1
# Case 1 passed!
# Tiempo de procesamiento  vectorial: 0:00:00.000021
# Case 2
# Case 2 passed!
# All tests passed!
# Tiempo de procesamiento  iterativo: 0:00:00.020024
# Iterative gradient at initial w, b (similar to)(-50.498559851122586 -6.988606075159082): -50.029784151847565 -7.038664734730416
# Tiempo de procesamiento  iterativo: 0:00:00.018673
# Iterative gradient at initial w, b (similar to)(-38.7005262336415 -5.369312042261976): -38.520037404853795 -5.440943519698437
# ----Compute iterative gradient POO-------
# Testing: compute_gradient_test
# Using X with shape (4, 1)
# Tiempo de procesamiento  iterativo: 0:00:00.000044
# Case 1
# Case 1 passed!
# Tiempo de procesamiento  iterativo: 0:00:00.000020
# Case 2
# Case 2 passed!
# All tests passed!
# <class 'numpy.float64'>
# Vectorial cost at initial w (35.841): 34.041
# ----Compute cost POO-------
# Testing: compute_cost_test
# Cost case 1
# Case 1 passed!
# Cost case 2
# Case 2 passed!
# Cost case 3
# Case 3 passed!
# Cost case 4
# Case 4 passed!
# Cost case 5
# Case 5 passed!
# All tests passed!
# <class 'numpy.float64'>
# Iterative cost at initial w (35.841): 34.041
# ----Compute iterative cost POO-------
# Testing: compute_cost_test
# Cost case 1
# Case 1 passed!
# Cost case 2
# Case 2 passed!
# Cost case 3
# Case 3 passed!
# Cost case 4
# Case 4 passed!
# Cost case 5
# Case 5 passed!
# All tests passed!
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000083
# Tiempo de procesamiento  vectorial: 0:00:00.000103
# Tiempo de procesamiento  vectorial: 0:00:00.000115
# Tiempo de procesamiento  vectorial: 0:00:00.000223
# Tiempo de procesamiento  vectorial: 0:00:00.000092
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000089
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000077
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000082
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000076
# Tiempo de procesamiento  vectorial: 0:00:00.000086
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000119
# Tiempo de procesamiento  vectorial: 0:00:00.000092
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000090
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000124
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000194
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000167
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000123
# Tiempo de procesamiento  vectorial: 0:00:00.000175
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000079
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000147
# Tiempo de procesamiento  vectorial: 0:00:00.000113
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000093
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000089
# Tiempo de procesamiento  vectorial: 0:00:00.000084
# Tiempo de procesamiento  vectorial: 0:00:00.000096
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000090
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000090
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000091
# Tiempo de procesamiento  vectorial: 0:00:00.000117
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000096
# Tiempo de procesamiento  vectorial: 0:00:00.000083
# Tiempo de procesamiento  vectorial: 0:00:00.000077
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000085
# Tiempo de procesamiento  vectorial: 0:00:00.000094
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000174
# Tiempo de procesamiento  vectorial: 0:00:00.000078
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000078
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000170
# Tiempo de procesamiento  vectorial: 0:00:00.000108
# Tiempo de procesamiento  vectorial: 0:00:00.000076
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000079
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000100
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000076
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000089
# Tiempo de procesamiento  vectorial: 0:00:00.000103
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000081
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000082
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000090
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000163
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000121
# Tiempo de procesamiento  vectorial: 0:00:00.000118
# Tiempo de procesamiento  vectorial: 0:00:00.000086
# Tiempo de procesamiento  vectorial: 0:00:00.000112
# Tiempo de procesamiento  vectorial: 0:00:00.000089
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000079
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000145
# Tiempo de procesamiento  vectorial: 0:00:00.000110
# Tiempo de procesamiento  vectorial: 0:00:00.000106
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000263
# Tiempo de procesamiento  vectorial: 0:00:00.000161
# Tiempo de procesamiento  vectorial: 0:00:00.000095
# Tiempo de procesamiento  vectorial: 0:00:00.000094
# Tiempo de procesamiento  vectorial: 0:00:00.000093
# Tiempo de procesamiento  vectorial: 0:00:00.000094
# Tiempo de procesamiento  vectorial: 0:00:00.000093
# Tiempo de procesamiento  vectorial: 0:00:00.000093
# Tiempo de procesamiento  vectorial: 0:00:00.000082
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000140
# Tiempo de procesamiento  vectorial: 0:00:00.000086
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000096
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000144
# Tiempo de procesamiento  vectorial: 0:00:00.000092
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000159
# Tiempo de procesamiento  vectorial: 0:00:00.000166
# Tiempo de procesamiento  vectorial: 0:00:00.000112
# Tiempo de procesamiento  vectorial: 0:00:00.000130
# Tiempo de procesamiento  vectorial: 0:00:00.000232
# Tiempo de procesamiento  vectorial: 0:00:00.000153
# Tiempo de procesamiento  vectorial: 0:00:00.000159
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000130
# Tiempo de procesamiento  vectorial: 0:00:00.000079
# Tiempo de procesamiento  vectorial: 0:00:00.000106
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000112
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000084
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000088
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000148
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000117
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000115
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000084
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000103
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000097
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000097
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000082
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000066
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000092
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000116
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000091
# Tiempo de procesamiento  vectorial: 0:00:00.000086
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000076
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000096
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000085
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000081
# Tiempo de procesamiento  vectorial: 0:00:00.000106
# Tiempo de procesamiento  vectorial: 0:00:00.000112
# Tiempo de procesamiento  vectorial: 0:00:00.000143
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000113
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000097
# Tiempo de procesamiento  vectorial: 0:00:00.000096
# Tiempo de procesamiento  vectorial: 0:00:00.000112
# ...
# Tiempo de procesamiento  vectorial: 0:00:00.000100
# Tiempo de procesamiento  vectorial: 0:00:00.000098
# Tiempo de procesamiento  vectorial: 0:00:00.000095
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000092
# Tiempo de procesamiento  vectorial: 0:00:00.000097
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000076
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000080
# Tiempo de procesamiento  vectorial: 0:00:00.000097
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000088
# Tiempo de procesamiento  vectorial: 0:00:00.000141
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000089
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000082
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000194
# Tiempo de procesamiento  vectorial: 0:00:00.000138
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000208
# Tiempo de procesamiento  vectorial: 0:00:00.000122
# Tiempo de procesamiento  vectorial: 0:00:00.000094
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000082
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000865
# Tiempo de procesamiento  vectorial: 0:00:00.000421
# Tiempo de procesamiento  vectorial: 0:00:00.000134
# Tiempo de procesamiento  vectorial: 0:00:00.000113
# Tiempo de procesamiento  vectorial: 0:00:00.000077
# Tiempo de procesamiento  vectorial: 0:00:00.000080
# Tiempo de procesamiento  vectorial: 0:00:00.008479
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000078
# Tiempo de procesamiento  vectorial: 0:00:00.000128
# Tiempo de procesamiento  vectorial: 0:00:00.000567
# Tiempo de procesamiento  vectorial: 0:00:00.000152
# Tiempo de procesamiento  vectorial: 0:00:00.000120
# Tiempo de procesamiento  vectorial: 0:00:00.000115
# Tiempo de procesamiento  vectorial: 0:00:00.000131
# Tiempo de procesamiento  vectorial: 0:00:00.000115
# Tiempo de procesamiento  vectorial: 0:00:00.000119
# Tiempo de procesamiento  vectorial: 0:00:00.000120
# Tiempo de procesamiento  vectorial: 0:00:00.000096
# Tiempo de procesamiento  vectorial: 0:00:00.000100
# Tiempo de procesamiento  vectorial: 0:00:00.000118
# Tiempo de procesamiento  vectorial: 0:00:00.000120
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000120
# Tiempo de procesamiento  vectorial: 0:00:00.000076
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000108
# Tiempo de procesamiento  vectorial: 0:00:00.000103
# Tiempo de procesamiento  vectorial: 0:00:00.000115
# Tiempo de procesamiento  vectorial: 0:00:00.000092
# Tiempo de procesamiento  vectorial: 0:00:00.000086
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000079
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000142
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000116
# Tiempo de procesamiento  vectorial: 0:00:00.000134
# Tiempo de procesamiento  vectorial: 0:00:00.000086
# Tiempo de procesamiento  vectorial: 0:00:00.000078
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000085
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000089
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000071
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000085
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000124
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000118
# Tiempo de procesamiento  vectorial: 0:00:00.000117
# Tiempo de procesamiento  vectorial: 0:00:00.000113
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000116
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000148
# Tiempo de procesamiento  vectorial: 0:00:00.000249
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000084
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000157
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000221
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000077
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000070
# Tiempo de procesamiento  vectorial: 0:00:00.000069
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000095
# Tiempo de procesamiento  vectorial: 0:00:00.000090
# Tiempo de procesamiento  vectorial: 0:00:00.000122
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000118
# Tiempo de procesamiento  vectorial: 0:00:00.000108
# Tiempo de procesamiento  vectorial: 0:00:00.000100
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000123
# Tiempo de procesamiento  vectorial: 0:00:00.000119
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000083
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000103
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000119
# Tiempo de procesamiento  vectorial: 0:00:00.000116
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000109
# Tiempo de procesamiento  vectorial: 0:00:00.000108
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000106
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000100
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000103
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000095
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000096
# Tiempo de procesamiento  vectorial: 0:00:00.000095
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000099
# Tiempo de procesamiento  vectorial: 0:00:00.000106
# Tiempo de procesamiento  vectorial: 0:00:00.000096
# Tiempo de procesamiento  vectorial: 0:00:00.000100
# Tiempo de procesamiento  vectorial: 0:00:00.000252
# Tiempo de procesamiento  vectorial: 0:00:00.000257
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000153
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000110
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000145
# Tiempo de procesamiento  vectorial: 0:00:00.000105
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000215
# Tiempo de procesamiento  vectorial: 0:00:00.000178
# Tiempo de procesamiento  vectorial: 0:00:00.000143
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000112
# Tiempo de procesamiento  vectorial: 0:00:00.000110
# Tiempo de procesamiento  vectorial: 0:00:00.000153
# Tiempo de procesamiento  vectorial: 0:00:00.000144
# Tiempo de procesamiento  vectorial: 0:00:00.000242
# Tiempo de procesamiento  vectorial: 0:00:00.000160
# Tiempo de procesamiento  vectorial: 0:00:00.000100
# Tiempo de procesamiento  vectorial: 0:00:00.000183
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000167
# Tiempo de procesamiento  vectorial: 0:00:00.000259
# Tiempo de procesamiento  vectorial: 0:00:00.000136
# Tiempo de procesamiento  vectorial: 0:00:00.000147
# Tiempo de procesamiento  vectorial: 0:00:00.000107
# Tiempo de procesamiento  vectorial: 0:00:00.000159
# Tiempo de procesamiento  vectorial: 0:00:00.000103
# Tiempo de procesamiento  vectorial: 0:00:00.000103
# Tiempo de procesamiento  vectorial: 0:00:00.000102
# Tiempo de procesamiento  vectorial: 0:00:00.000116
# Tiempo de procesamiento  vectorial: 0:00:00.000118
# Tiempo de procesamiento  vectorial: 0:00:00.000118
# Tiempo de procesamiento  vectorial: 0:00:00.000129
# Tiempo de procesamiento  vectorial: 0:00:00.000117
# Tiempo de procesamiento  vectorial: 0:00:00.000116
# Tiempo de procesamiento  vectorial: 0:00:00.000158
# Tiempo de procesamiento  vectorial: 0:00:00.000121
# Tiempo de procesamiento  vectorial: 0:00:00.000111
# Tiempo de procesamiento  vectorial: 0:00:00.000110
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000084
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000106
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000068
# Tiempo de procesamiento  vectorial: 0:00:00.000067
# Tiempo de procesamiento  vectorial: 0:00:00.000128
# Tiempo de procesamiento  vectorial: 0:00:00.000129
# Tiempo de procesamiento  vectorial: 0:00:00.000211
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000120
# Tiempo de procesamiento  vectorial: 0:00:00.000189
# Tiempo de procesamiento  vectorial: 0:00:00.000119
# Tiempo de procesamiento  vectorial: 0:00:00.000112
# Tiempo de procesamiento  vectorial: 0:00:00.002038
# Tiempo de procesamiento  vectorial: 0:00:00.000214
# Tiempo de procesamiento  vectorial: 0:00:00.000075
# Tiempo de procesamiento  vectorial: 0:00:00.000135
# Tiempo de procesamiento  vectorial: 0:00:00.000109
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000114
# Tiempo de procesamiento  vectorial: 0:00:00.000101
# Tiempo de procesamiento  vectorial: 0:00:00.000110
# Tiempo de procesamiento  vectorial: 0:00:00.000104
# Tiempo de procesamiento  vectorial: 0:00:00.000073
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000072
# Tiempo de procesamiento  vectorial: 0:00:00.000074
# Tiempo de procesamiento  vectorial: 0:00:00.000080
# for score 3.5, we predict user score of (3.97) 4.24
# 4.2435175926345305
# Case 1
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 31
#      29 test_cost_iterative(X,y)
#      30 test_w, test_b = 0,0
# ---> 31 test_gradient_descent(X,y,test_w,test_b)
#      32 test_gradient_descent_iterative(X,y,test_w,test_b)
#
# File c:\Users\jorda\Documents\Universidad\Anotaciones24-25\AA\Práctias\P1\practica01.py:86, in test_gradient_descent(x_train, y_train, w, b)
#      84 print(predict1)
#      85 print("Case 1")
# ---> 86 assert np.isclose(predict1, 3.96667965 ), f"Cost must be 3.966 for a perfect prediction but got {predict1}"
#      87 print("Case 1 passed!")
#      90 lr = LinearReg(x_train,y_train,w,b)
#
# AssertionError: Cost must be 3.966 for a perfect prediction but got 4.2435175926345305
