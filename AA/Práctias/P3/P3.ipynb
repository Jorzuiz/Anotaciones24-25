# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import utils
from LogisticRegressionMulti import LogisticRegMulti
import practica03

#name,platform,r-date,score,user score,developer,genre,players,critics,users
X, y = utils.load_data_csv_multi_logistic('data/games-data.csv','score','critics','users','user score')
#Ej1
X[:,0], mu0, sigma = utils.zscore_normalize_features(X[:,0])
X[:,1], mu1, sigma = utils.zscore_normalize_features(X[:,1])
X[:,2], mu2, sigma = utils.zscore_normalize_features(X[:,2])
#X[:,0]=X[:,0]+mu0
display(X[:,0])
display(y)

# initial_w = np.zeros(X.shape[1])
# initial_b = 0
# lr = LogisticRegMulti(X,y,initial_w,initial_b,lambda_=0)
# w,b,h,w_init,b_init = lr.gradient_descent(alpha = 0.01,num_iters=1500)

plt.scatter(X[:,0], y, marker = '.')
plt.xlabel('score')
plt.ylabel('user score')
plt.show()
plt.scatter(X[:,1], y, marker = '.')
plt.xlabel('critics')
plt.ylabel('user score')
plt.show()
plt.scatter(X[:,2], y, marker = '.')
plt.xlabel('users')
plt.ylabel('user score')
plt.show()


practica03.test_cost(X,y)
practica03.test_gradient(X,y)
practica03.test_gradient_descent(X,y)
# Out:
# ------------test_cost-----------
# ---Original---
# All tests passed!
# ---POO---
# All tests passed!
# ------------test_gradient-----------
# ---Original---
# All tests passed!
# ---POO---
# All tests passed!
# ---- Gradient descent POO--- lamb  0
# w,b found by gradient descent with labmda 0 ([ 0.93305656  0.18903186 -0.12087087] 0.4690649858291144): [ 0.93305656  0.18903186 -0.12087087] 0.4690649858291144
# ---- Gradient descent POO--- lamb  1
# w,b found by gradient descent with labmda 1 ([ 0.93278101  0.18900175 -0.12080013] 0.46905464164492655): [ 0.93278101  0.18900175 -0.12080013] 0.46905464164492655
# array([ 2.2637034 ,  2.18295864,  2.18295864, ..., -4.35736681,
#        -4.43811157, -4.84183537])
# array([1, 1, 1, ..., 0, 0, 0])
# ------------test_cost-----------
# ---Original---
# All tests passed!
# ---POO---
# All tests passed!
# ------------test_gradient-----------
# ---Original---
# All tests passed!
# ---POO---
# All tests passed!
# ...
